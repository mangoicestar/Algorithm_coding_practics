# %% [markdown]
# ## Training
# ### get latest 2hrs spc raw data from solr (almost 250 recs)
# - http://10.160.29.112:8983/solr/spc/select?q=*%3A*&rows=250&sort=timestamp%20desc&start=0

# %%
import json, requests, datetime, sqlite3
import pandas as pd
import numpy as np

# %%
def to_sqlite(data, table):
    conn = sqlite3.connect("algorithm.db")
    data.to_sql(table, conn, if_exists='append',index=False)
    conn.commit()
    conn.close()

# %%
# url="http://10.160.29.112:8983/solr/spc/select?q=*%3A*&rows=3&sort=timestamp%20desc&start=0"
# r = requests.request('GET', url)
# print(type(r.json()))
# print(r.json())

# %%
# results=r.json()['response']['docs']
# print(results)

# %%
results=[{'SPC_47': 0, 'SPC_24': '12.989', 'SPC_22': '0', 'SPC_36': '999', 'SPC_33': '210', 'SPC_11': '45.1', 'SPC_13': '1.901', 'SPC_6': '10.454', 'SPC_28': '88.723', 'SPC_58': 0, 'SPC_51': 0, 'SPC_40': '90.412', 'SPC_17': '0.41', 'timestamp': '1569493693.87931', 'SPC_30': '48.9', 'SPC_61': 0, 'RD_618': 160541, 'SPC_0': 160541, 'SPC_25': '4.596', 'SPC_52': 0, 'SPC_14': '0.309', 'SPC_29': '31.9', 'SPC_57': '17.085', 'SPC_41': 8801, 'SPC_18': '359.4', 'SPC_9': '24.39', 'SPC_39': '25.812', 'SPC_19': '713.6', 'SPC_55': '2.319', 'SPC_44': 0, 'SPC_5': '48.066', 'SPC_35': '999', 'SPC_1': 182754, 'SPC_46': 0, 'SPC_42': 0, 'SPC_56': '27.381', 'SPC_53': 0, 'id': 'A011569493693.87931', 'SPC_45': 0, 'SPC_8': '88.435', 'SPC_10': '67.14', 'machine_id': 'A01', 'SPC_21': '135', 'SPC_4': '18.096', 'SPC_49': 0, 'SPC_32': '210.1', 'SPC_34': '195', 'SPC_15': '1.72', 'SPC_26': '0', 'SPC_38': 13000, 'SPC_2': '2.532', 'SPC_16': '0', 'SPC_7': '10.497', 'SPC_27': '474.664', 'SPC_54': 0, 'SPC_43': 0, 'SPC_12': '2.56', 'SPC_23': '199.523', 'SPC_50': 0, 'SPC_59': 0, 'timestamp_iso': '2019-09-26T18:28:13.879Z', 'source_path': '/data/MMIA/A01/2019-09-26/hcsData/20190926180001_Spc.csv', 'SPC_48': 0, 'SPC_60': 0, 'SPC_3': '7', 'SPC_37': '35', 'SPC_31': '230', 'SPC_20': '54.9', '_version_': 1645733432022532096}, {'SPC_47': 0, 'SPC_24': '37.994', 'SPC_22': '45.1', 'SPC_36': '999', 'SPC_33': '225', 'SPC_11': '52.7', 'SPC_13': '3.195', 'SPC_6': '10.544', 'SPC_28': '75.842', 'SPC_58': 0, 'SPC_51': 0, 'SPC_40': '76.246', 'SPC_17': '0.251', 'timestamp': '1569493687.88478', 'SPC_30': '53.5', 'SPC_61': 0, 'RD_618': 93150, 'SPC_0': 93150, 'SPC_25': '5.427', 'SPC_52': 0, 'SPC_14': '0.605', 'SPC_29': '27.9', 'SPC_57': '27.43', 'SPC_41': 15881, 'SPC_18': '304.9', 'SPC_9': '39.28', 'SPC_39': '19.031', 'SPC_19': '493.3', 'SPC_55': '4.4', 'SPC_44': 0, 'SPC_5': '33.014', 'SPC_35': '209.8', 'SPC_1': 182648, 'SPC_46': 0, 'SPC_42': 0, 'SPC_56': '19.238', 'SPC_53': 0, 'id': 'A051569493687.88478', 'SPC_45': 0, 'SPC_8': '70.687', 'SPC_10': '51.71', 'machine_id': 'A05', 'SPC_21': '261.4', 'SPC_4': '18.077', 'SPC_49': 0, 'SPC_32': '225', 'SPC_34': '220.1', 'SPC_15': '0.53', 'SPC_26': '0', 'SPC_38': 20500, 'SPC_2': '2.354', 'SPC_16': '0.186', 'SPC_7': '9.841', 'SPC_27': '581.774', 'SPC_54': 0, 'SPC_43': 0, 'SPC_12': '4.04', 'SPC_23': '0', 'SPC_50': 0, 'SPC_59': 0, 'timestamp_iso': '2019-09-26T18:28:07.884Z', 'source_path': '/data/MMIA/A05/2019-09-26/hcsData/20190926180001_Spc.csv', 'SPC_48': 0, 'SPC_60': 0, 'SPC_3': '5.051', 'SPC_37': '52', 'SPC_31': '220.1', 'SPC_20': '151.2', '_version_': 1645733424424550402}, {'SPC_47': 0, 'SPC_24': '15.279', 'SPC_22': '27.4', 'SPC_36': '995', 'SPC_33': '230', 'SPC_11': '35', 'SPC_13': '3.12', 'SPC_6': '17.011', 'SPC_28': '58.333', 'SPC_58': 0, 'SPC_51': 0, 'SPC_40': '58.405', 'SPC_17': '0.175', 'timestamp': '1569493681.87325', 'SPC_30': '55.4', 'SPC_61': 0, 'RD_618': 9980, 'SPC_0': 9980, 'SPC_25': '0', 'SPC_52': 0, 'SPC_14': '0.44', 'SPC_29': '27.2', 'SPC_57': '20.84', 'SPC_41': 12128, 'SPC_18': '332.4', 'SPC_9': '35.92', 'SPC_39': '31.049', 'SPC_19': '1047.9', 'SPC_55': '1.281', 'SPC_44': 0, 'SPC_5': '40.43', 'SPC_35': '210', 'SPC_1': 182635, 'SPC_46': 0, 'SPC_42': 0, 'SPC_56': '31.421', 'SPC_53': 0, 'id': 'A061569493681.87325', 'SPC_45': 0, 'SPC_8': '53.402', 'SPC_10': '71.816', 'machine_id': 'A06', 'SPC_21': '235.1', 'SPC_4': '25.1', 'SPC_49': 0, 'SPC_32': '230', 'SPC_34': '224.9', 'SPC_15': '1.469', 'SPC_26': '0', 'SPC_38': 5900, 'SPC_2': '2.829', 'SPC_16': '0.494', 'SPC_7': '17.007', 'SPC_27': '568.862', 'SPC_54': 0, 'SPC_43': 0, 'SPC_12': '3.395', 'SPC_23': '112.58', 'SPC_50': 0, 'SPC_59': 0, 'timestamp_iso': '2019-09-26T18:28:01.873Z', 'source_path': '/data/MMIA/A06/2019-09-26/hcsData/20190926180001_Spc.csv', 'SPC_48': 0, 'SPC_60': 0, 'SPC_3': '4.85', 'SPC_37': '53', 'SPC_31': '230', 'SPC_20': '70', '_version_': 1645733420615073792}]

# %%
for i in results:
    print(i, "\n")
# Out:
# {'SPC_47': 0, 'SPC_24': '12.989', 'SPC_22': '0', 'SPC_36': '999', 'SPC_33': '210', 'SPC_11': '45.1', 'SPC_13': '1.901', 'SPC_6': '10.454', 'SPC_28': '88.723', 'SPC_58': 0, 'SPC_51': 0, 'SPC_40': '90.412', 'SPC_17': '0.41', 'timestamp': '1569493693.87931', 'SPC_30': '48.9', 'SPC_61': 0, 'RD_618': 160541, 'SPC_0': 160541, 'SPC_25': '4.596', 'SPC_52': 0, 'SPC_14': '0.309', 'SPC_29': '31.9', 'SPC_57': '17.085', 'SPC_41': 8801, 'SPC_18': '359.4', 'SPC_9': '24.39', 'SPC_39': '25.812', 'SPC_19': '713.6', 'SPC_55': '2.319', 'SPC_44': 0, 'SPC_5': '48.066', 'SPC_35': '999', 'SPC_1': 182754, 'SPC_46': 0, 'SPC_42': 0, 'SPC_56': '27.381', 'SPC_53': 0, 'id': 'A011569493693.87931', 'SPC_45': 0, 'SPC_8': '88.435', 'SPC_10': '67.14', 'machine_id': 'A01', 'SPC_21': '135', 'SPC_4': '18.096', 'SPC_49': 0, 'SPC_32': '210.1', 'SPC_34': '195', 'SPC_15': '1.72', 'SPC_26': '0', 'SPC_38': 13000, 'SPC_2': '2.532', 'SPC_16': '0', 'SPC_7': '10.497', 'SPC_27': '474.664', 'SPC_54': 0, 'SPC_43': 0, 'SPC_12': '2.56'
# ...

# %%
pd.set_option('display.max_columns', 70)
df = pd.DataFrame(json.loads(json.dumps(results)))

# %%
print(list(df))
# Out:
# ['RD_618', 'SPC_0', 'SPC_1', 'SPC_10', 'SPC_11', 'SPC_12', 'SPC_13', 'SPC_14', 'SPC_15', 'SPC_16', 'SPC_17', 'SPC_18', 'SPC_19', 'SPC_2', 'SPC_20', 'SPC_21', 'SPC_22', 'SPC_23', 'SPC_24', 'SPC_25', 'SPC_26', 'SPC_27', 'SPC_28', 'SPC_29', 'SPC_3', 'SPC_30', 'SPC_31', 'SPC_32', 'SPC_33', 'SPC_34', 'SPC_35', 'SPC_36', 'SPC_37', 'SPC_38', 'SPC_39', 'SPC_4', 'SPC_40', 'SPC_41', 'SPC_42', 'SPC_43', 'SPC_44', 'SPC_45', 'SPC_46', 'SPC_47', 'SPC_48', 'SPC_49', 'SPC_5', 'SPC_50', 'SPC_51', 'SPC_52', 'SPC_53', 'SPC_54', 'SPC_55', 'SPC_56', 'SPC_57', 'SPC_58', 'SPC_59', 'SPC_6', 'SPC_60', 'SPC_61', 'SPC_7', 'SPC_8', 'SPC_9', '_version_', 'id', 'machine_id', 'source_path', 'timestamp', 'timestamp_iso']

# %%
for i in list(df):
    if i.split("_")[0] == "SPC": 
        print(round(df[i].astype(float), 2))
        df[i]=round(df[i].astype(float), 2)
#         round(df[i].astype(float), 2)
# Out:
# 0    160541.0
# 1     93150.0
# 2      9980.0
# Name: SPC_0, dtype: float64
# 0    182754.0
# 1    182648.0
# 2    182635.0
# Name: SPC_1, dtype: float64
# 0    67.14
# 1    51.71
# 2    71.82
# Name: SPC_10, dtype: float64
# 0    45.1
# 1    52.7
# 2    35.0
# Name: SPC_11, dtype: float64
# 0    2.56
# 1    4.04
# 2    3.40
# Name: SPC_12, dtype: float64
# 0    1.90
# 1    3.20
# 2    3.12
# Name: SPC_13, dtype: float64
# 0    0.31
# 1    0.60
# 2    0.44
# Name: SPC_14, dtype: float64
# 0    1.72
# 1    0.53
# 2    1.47
# Name: SPC_15, dtype: float64
# 0    0.00
# 1    0.19
# 2    0.49
# Name: SPC_16, dtype: float64
# 0    0.41
# 1    0.25
# 2    0.18
# Name: SPC_17, dtype: float64
# 0    359.4
# 1    304.9
# 2    332.4
# Name: SPC_18, dtype: float64
# 0     713.6
# 1     493.3
# 2    1047.9
# Name: SPC_19, dtype: float64
# 0    2.53
# 1    2.35
# 2    2.83
# Name: SPC_2, dtype: float64
# 0     54.9
# 1    151.2
# 2     70.0
# Name: SPC_20, dtype: float64
# 0    135.0
# 1    261.4
# ...

# %%
df
# Out:
#    RD_618     SPC_0     SPC_1  SPC_10  SPC_11  SPC_12  SPC_13  SPC_14  SPC_15  \
# 0  160541  160541.0  182754.0   67.14    45.1    2.56    1.90    0.31    1.72
# 1   93150   93150.0  182648.0   51.71    52.7    4.04    3.20    0.60    0.53
# 2    9980    9980.0  182635.0   71.82    35.0    3.40    3.12    0.44    1.47
#
#    SPC_16  SPC_17  SPC_18  SPC_19  SPC_2  SPC_20  SPC_21  SPC_22  SPC_23  \
# 0    0.00    0.41   359.4   713.6   2.53    54.9   135.0     0.0  199.52
# 1    0.19    0.25   304.9   493.3   2.35   151.2   261.4    45.1    0.00
# 2    0.49    0.18   332.4  1047.9   2.83    70.0   235.1    27.4  112.58
#
#    SPC_24  SPC_25  SPC_26  SPC_27  SPC_28  SPC_29  SPC_3  SPC_30  SPC_31  \
# 0   12.99    4.60     0.0  474.66   88.72    31.9   7.00    48.9   230.0
# 1   37.99    5.43     0.0  581.77   75.84    27.9   5.05    53.5   220.1
# 2   15.28    0.00     0.0  568.86   58.33    27.2   4.85    55.4   230.0
#
# ...

# %%
now=datetime.datetime.now()
print(now)
# Out:
# 2019-10-01 11:52:43.354469

# %%
# bound=pd.DataFrame([df.mean(), df.std()]).T
bound=pd.DataFrame([df.mean(), df.std()]).T
bound.reset_index(drop=False,inplace=True)
bound.columns = ['spc_name','mean','std']
bound['mean']=round(bound['mean'],2)
bound['std']=round(bound['std'],2)
bound['timestamp']=now

# %%
# CREATE TABLE "mu_std" (
# 	"spc_name"	TEXT,
# 	"mean"	NUMERIC,
# 	"std"	REAL,
# 	"timestamp"	NUMERIC
# )

def to_sqlite(data, table):
    conn = sqlite3.connect("algorithm.db")
    data.to_sql(table, conn, if_exists='append',index=False)
    conn.commit()
    conn.close()

# %%
to_sqlite(bound, "mu_std")

# %%
bound
# Out:
#      spc_name          mean           std                  timestamp
# 0      RD_618  8.789033e+04  7.541818e+04 2019-10-01 11:52:43.354469
# 1       SPC_0  8.789033e+04  7.541818e+04 2019-10-01 11:52:43.354469
# 2       SPC_1  1.826790e+05  6.528000e+01 2019-10-01 11:52:43.354469
# 3      SPC_10  6.356000e+01  1.052000e+01 2019-10-01 11:52:43.354469
# 4      SPC_11  4.427000e+01  8.880000e+00 2019-10-01 11:52:43.354469
# 5      SPC_12  3.330000e+00  7.400000e-01 2019-10-01 11:52:43.354469
# 6      SPC_13  2.740000e+00  7.300000e-01 2019-10-01 11:52:43.354469
# 7      SPC_14  4.500000e-01  1.500000e-01 2019-10-01 11:52:43.354469
# 8      SPC_15  1.240000e+00  6.300000e-01 2019-10-01 11:52:43.354469
# 9      SPC_16  2.300000e-01  2.500000e-01 2019-10-01 11:52:43.354469
# 10     SPC_17  2.800000e-01  1.200000e-01 2019-10-01 11:52:43.354469
# 11     SPC_18  3.322300e+02  2.725000e+01 2019-10-01 11:52:43.354469
# 12     SPC_19  7.516000e+02  2.792500e+02 2019-10-01 11:52:43.354469
# ...

# %%
bound.to_csv('test.csv')

# %%
bound_2=bound.set_index("spc_name")
bound_2['upper']=round(bound_2['mean']+bound_2['std']*6 ,2)
bound_2['lower']=round(bound_2['mean']-bound_2['std']*6 ,2)

# %%
bound_2
# Out:
#                    mean           std                  timestamp  \
# spc_name
# RD_618     8.789033e+04  7.541818e+04 2019-10-01 11:52:43.354469
# SPC_0      8.789033e+04  7.541818e+04 2019-10-01 11:52:43.354469
# SPC_1      1.826790e+05  6.528000e+01 2019-10-01 11:52:43.354469
# SPC_10     6.356000e+01  1.052000e+01 2019-10-01 11:52:43.354469
# SPC_11     4.427000e+01  8.880000e+00 2019-10-01 11:52:43.354469
# SPC_12     3.330000e+00  7.400000e-01 2019-10-01 11:52:43.354469
# SPC_13     2.740000e+00  7.300000e-01 2019-10-01 11:52:43.354469
# SPC_14     4.500000e-01  1.500000e-01 2019-10-01 11:52:43.354469
# SPC_15     1.240000e+00  6.300000e-01 2019-10-01 11:52:43.354469
# SPC_16     2.300000e-01  2.500000e-01 2019-10-01 11:52:43.354469
# SPC_17     2.800000e-01  1.200000e-01 2019-10-01 11:52:43.354469
# SPC_18     3.322300e+02  2.725000e+01 2019-10-01 11:52:43.354469
# SPC_19     7.516000e+02  2.792500e+02 2019-10-01 11:52:43.354469
# ...

# %% [markdown]
# ## inference data
# ### 拿最新一筆的 SPC data ，計算每個參數值 (是否超過 upper / lower bound)

# %%
#### get spc_data

# url="http://10.160.29.112:8983/solr/spc/select?q=*%3A*&rows=1&sort=timestamp%20desc&start=0"

# r = requests.get('http://localhost:6011/api/readAnomalyDetection')
# r = requests.request('GET', url)
# results=r.json()['response']['docs'][0]
results={'SPC_47': 0, 'SPC_24': '26.792', 'SPC_22': '49', 'SPC_36': '999', 'SPC_33': '295.2', 'SPC_11': '117.2', 'SPC_13': '2.894', 'SPC_6': '13.008', 'SPC_28': '121.968', 'SPC_58': 0, 'SPC_51': 0, 'SPC_40': '122.425', 'SPC_17': '0.426', 'timestamp': '1569492421.86828', 'SPC_30': '56.2', 'SPC_61': 0, 'RD_618': 613910, 'SPC_0': 613910, 'SPC_25': '3.548', 'SPC_52': 0, 'SPC_14': '0.655', 'SPC_29': '34.3', 'SPC_57': '23.165', 'SPC_41': 6817, 'SPC_18': '366.1', 'SPC_9': '28.971', 'SPC_39': '19.775', 'SPC_19': '875.3', 'SPC_55': '0', 'SPC_44': 0, 'SPC_5': '59.34', 'SPC_35': '999', 'SPC_1': 180422, 'SPC_46': 0, 'SPC_42': 0, 'SPC_56': '21.015', 'SPC_53': 0, 'id': 'A031569492421.86828', 'SPC_45': 0, 'SPC_8': '115.516', 'SPC_10': '68.477', 'machine_id': 'A03', 'SPC_21': '176.9', 'SPC_4': '20.077', 'SPC_49': 0, 'SPC_32': '294.9', 'SPC_34': '280.1', 'SPC_15': '1.925', 'SPC_26': '0', 'SPC_38': 41000, 'SPC_2': '1.265', 'SPC_16': '0.165', 'SPC_7': '13.022', 'SPC_27': '470.574', 'SPC_54': 0, 'SPC_43': 0, 'SPC_12': '2.92', 'SPC_23': '0', 'SPC_50': 0, 'SPC_59': 0, 'timestamp_iso': '2019-09-26T18:07:01.868Z', 'source_path': '/data/MMIA/A03/2019-09-26/hcsData/20190926180001_Spc.csv', 'SPC_48': 0, 'SPC_60': 0, 'SPC_3': '11.32', 'SPC_37': '41', 'SPC_31': '300', 'SPC_20': '114.9', '_version_': 1645732094722179072}
print(results)
# Out:
# {'SPC_47': 0, 'SPC_24': '26.792', 'SPC_22': '49', 'SPC_36': '999', 'SPC_33': '295.2', 'SPC_11': '117.2', 'SPC_13': '2.894', 'SPC_6': '13.008', 'SPC_28': '121.968', 'SPC_58': 0, 'SPC_51': 0, 'SPC_40': '122.425', 'SPC_17': '0.426', 'timestamp': '1569492421.86828', 'SPC_30': '56.2', 'SPC_61': 0, 'RD_618': 613910, 'SPC_0': 613910, 'SPC_25': '3.548', 'SPC_52': 0, 'SPC_14': '0.655', 'SPC_29': '34.3', 'SPC_57': '23.165', 'SPC_41': 6817, 'SPC_18': '366.1', 'SPC_9': '28.971', 'SPC_39': '19.775', 'SPC_19': '875.3', 'SPC_55': '0', 'SPC_44': 0, 'SPC_5': '59.34', 'SPC_35': '999', 'SPC_1': 180422, 'SPC_46': 0, 'SPC_42': 0, 'SPC_56': '21.015', 'SPC_53': 0, 'id': 'A031569492421.86828', 'SPC_45': 0, 'SPC_8': '115.516', 'SPC_10': '68.477', 'machine_id': 'A03', 'SPC_21': '176.9', 'SPC_4': '20.077', 'SPC_49': 0, 'SPC_32': '294.9', 'SPC_34': '280.1', 'SPC_15': '1.925', 'SPC_26': '0', 'SPC_38': 41000, 'SPC_2': '1.265', 'SPC_16': '0.165', 'SPC_7': '13.022', 'SPC_27': '470.574', 'SPC_54': 0, 'SPC_43': 0, 'S
# ...

# %%
# for i in results:
#     print(i + " = \t\t " + str(results[i]))
print(results["SPC_24"])
# Out:
# 26.792

# %%
upper=dict(bound_2.get("upper"))
lower=dict(bound_2.get("lower"))
# print(upper.get("SPC_4"))
print(upper)
print("\n")
print(lower)
# Out:
# {'RD_618': 540399.41, 'SPC_0': 540399.41, 'SPC_1': 183070.68, 'SPC_10': 126.68, 'SPC_11': 97.55, 'SPC_12': 7.77, 'SPC_13': 7.12, 'SPC_14': 1.35, 'SPC_15': 5.02, 'SPC_16': 1.73, 'SPC_17': 1.0, 'SPC_18': 495.73, 'SPC_19': 2427.1, 'SPC_2': 4.01, 'SPC_20': 402.77, 'SPC_21': 610.64, 'SPC_22': 160.49, 'SPC_23': 704.21, 'SPC_24': 105.01, 'SPC_25': 20.92, 'SPC_26': 0.0, 'SPC_27': 892.58, 'SPC_28': 165.8, 'SPC_29': 44.24, 'SPC_3': 12.77, 'SPC_30': 72.64, 'SPC_31': 261.02, 'SPC_32': 283.8, 'SPC_33': 284.13, 'SPC_34': 309.69, 'SPC_35': 3206.47, 'SPC_36': 1011.53, 'SPC_37': 107.39, 'SPC_38': 56938.79, 'SPC_39': 61.48, 'SPC_4': 44.73, 'SPC_40': 171.26, 'SPC_41': 33522.84, 'SPC_42': 0.0, 'SPC_43': 0.0, 'SPC_44': 0.0, 'SPC_45': 0.0, 'SPC_46': 0.0, 'SPC_47': 0.0, 'SPC_48': 0.0, 'SPC_49': 0.0, 'SPC_5': 85.68, 'SPC_50': 0.0, 'SPC_51': 0.0, 'SPC_52': 0.0, 'SPC_53': 0.0, 'SPC_54': 0.0, 'SPC_55': 12.21, 'SPC_56': 63.21, 'SPC_57': 53.22, 'SPC_58': 0.0, 'SPC_59': 0.0, 'SPC_6': 35.23, 'SPC_60': 0.0, 'SPC_61
# ...

# %%
##### 
defect = np.array(list(map(lambda x: int((x>upper[j])|(x<lower[j])), df[i])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-546856532fbe> in <module>()
#       1
#       2 #####
# ----> 3 defect = np.array(list(map(lambda x: int((x>upper[j])|(x<lower[j])), df[i])))
#
# <ipython-input-28-546856532fbe> in <lambda>(x)
#       1
#       2 #####
# ----> 3 defect = np.array(list(map(lambda x: int((x>upper[j])|(x<lower[j])), df[i])))
#
# NameError: name 'j' is not defined
